# %% [markdown]
# <table style="width:100%">
#   <tr>
#     <td valign="top"><img src="../data/img/FER_logo_2.png" width=300 height=80 align="left"></td>
#     <td valign="top"><img src="../data/img/LARES_2_transparent.png" width=250 height=80 align="right"></td>
#   </tr>
#  </table>

# %% [markdown]
# # Iris dataset - Classification
# [//]: #![valentine](../data/img/valentine.png)
# ![iris_croatica](../data/img/iris_croatica.jpg)

# %% [markdown]
# ## Import modules

# %%
import pandas as pd
import numpy as np
import pickle
import warnings # current version of seaborn generates a bunch of warnings
warnings.filterwarnings("ignore") # ignore seaborn warnings

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid", color_codes=True)

from matplotlib.colors import ListedColormap

tex_fonts = {
    # Use LaTeX to write all text
    "text.usetex": False,
    "font.family": "serif",
    # Use 26pt font in plots
    "axes.labelsize": 16,
    "font.size": 16,
    "figure.titlesize": 16,
    # Make the legend/label fonts a little smaller
    "legend.title_fontsize": 14,
    "legend.fontsize": 14,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14
}

plt.rcParams.update(tex_fonts)

#%pylab inline
# %matplotlib inline
# %matplotlib notebook
# %config InlineBackend.figure_format='svg'
plt.rcParams['figure.figsize'] = (10, 8)

# %%
# Decision Tree classifier
from sklearn.tree import DecisionTreeClassifier
# Decision tree visualization
from sklearn import tree
# Calculating accuracy and evaluating the model
from sklearn.metrics import accuracy_score, classification_report
# SVC
from sklearn.svm import SVC
# Scaling the data
from sklearn.preprocessing import StandardScaler
# KNN classifier
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## Auxiliary functions

# %%
def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):
    
    num2label = {0: "Iris-setosa", 1: "Iris-versicolor", 2: "Iris-virginica"}

    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.4, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[(y.values == cl).ravel(), 0], y=X[(y.values == cl).ravel(), 1],
                    alpha=0.8, color=cmap(idx),
                    marker=markers[idx], label=num2label.get(cl))
    
    plt.legend()

# %% [markdown]
# ## Supervised learning for regression
# 0. Preprocess data
#
# 1. Create/build model
#
# 2. Tune model
#
# 3. Evaluate model
#
# 4. Hands on

# %% [markdown]
# ## 0. (Pre)process data
# ![iris_dataset](../data/img/iris-dataset.png)

# %%
X_train = pd.read_csv("../data/iris/X_train.csv", index_col='Id')
y_train = pd.read_csv("../data/iris/y_train.csv", index_col='Id')
X_test = pd.read_csv("../data/iris/X_test.csv", index_col='Id')
y_test = pd.read_csv("../data/iris/y_test.csv", index_col='Id')

# %% [markdown]
# ## 1. Create/Build model - Classification

# %% [markdown]
# ### Gini index

# %%
# from sklearn.tree import DecisionTreeClassifier
classifier_gini = DecisionTreeClassifier(criterion = "gini", # criterium
                                         max_depth = 5, # max tree height
                                         min_samples_leaf = 3, # max leaf samples
                                         random_state = 100)

# %% [markdown]
# We have different methods
# - fit() - fit the model, i.e. learn
# - predict() - use learned parameters from .fit() and get predictions
# - fit_predict() - does fitting and prediciting over the same dataset

# %% [markdown]
# ## 2. Fit model
# Train the model.

# %%
classifier_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=3, random_state=100)

# %% [markdown]
# ## 3. Evaluate the model
# Make predictions for the test dataset and get some evaluation measurements.

# %%
y_pred_gini = classifier_gini.predict(X_test)

# %%
print("Accuracy: ", accuracy_score(y_test, y_pred_gini)*100)
print("Report: ", classification_report(y_test, y_pred_gini))
# Out:
# Accuracy:  96.66666666666667
# Report:                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.91      1.00      0.95        10
#            2       1.00      0.90      0.95        10
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ### Plotting - Visualize the tree

# %%
tree.plot_tree(classifier_gini);

# %% [markdown]
# #### Add some color

# %%
fn = ['Sepal length', 'Sepal width', 'Petal length', 'Petal width']
cn = ['Setosa', 'Versicolor', 'Virginica']
fig, axes = plt.subplots(nrows=1, ncols=1)
tree.plot_tree(classifier_gini, feature_names=fn, class_names=cn, filled=True);

# %%
# If you're satisfied with the model, save it to disk
filename = '../models/classifier_gini.pkl'
pickle.dump(classifier_gini, open(filename, 'wb'))
 
# load the model from disk
# classifier_gini = pickle.load(open(filename, 'rb'))
# result = classifier_gini.predict(X_test)

# %% [markdown]
# ## Hands on
# Using the same approach create, fit and evaluate a classification model with "entropy" criterion.

# %% [markdown]
# ## 1. Create/Build model/classifier

# %% [markdown]
# ### Entropy

# %%
#HANDS ON
# classifier_entropy = DecisionTreeClassifier(criterion = ??,
#                                             max_depth = ??,
#                                             min_samples_leaf = ??,
#                                             random_state = 100)

classifier_entropy = DecisionTreeClassifier(criterion = "entropy",
                                            max_depth = 2,
                                            min_samples_leaf = 3,
                                            random_state = 100)

# %% [markdown]
# ## 2. Fit model
# Train the model.

# %%
# HANDS ON
# classifier_entropy.fit(X_train, y_train)

classifier_entropy.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=2, min_samples_leaf=3,
#                        random_state=100)

# %% [markdown]
# ## 3. Evaluate the model

# %%
# HANDS ON
# y_pred_entropy = ??

y_pred_entropy = classifier_entropy.predict(X_test)

# %%
print("Accuracy: ", accuracy_score(y_test, y_pred_entropy)*100)
print("Report: ", classification_report(y_test, y_pred_entropy))
# Out:
# Accuracy:  93.33333333333333
# Report:                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.90      0.90      0.90        10
#            2       0.90      0.90      0.90        10
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
tree.plot_tree(classifier_entropy, feature_names=fn, class_names=cn, filled=True);

# %%
# If you're satisfied with the model, save it to disk
filename = '../models/classifier_entropy.pkl'
pickle.dump(classifier_entropy, open(filename, 'wb'))
 
# load the model from disk
# classifier_entropy = pickle.load(open(filename, 'rb'))
# result = classifier_entropy.predict(X_test)

# %% [markdown]
# ## Linear SVC
# ## 0. (Pre)process data

# %%
# We'll use the petal length and width for this analysis
X_test = X_test[['PetalLengthCm', 'PetalWidthCm']]
X_train = X_train[['PetalLengthCm', 'PetalWidthCm']]

# %% [markdown]
# ### Scale the data
# Here we use StandardScaler from sklearn.preprocessing
#
# Standardize features by removing the mean and scaling to unit variance. The standard score of a sample x is calculated as:
# \begin{equation}
# \Large{z = \frac{x - u}{s}},
# \end{equation}
# where $u$ and $s$ are the mean and std of the sample, respectively

# %% [markdown]
# #### Define the scaler

# %%
scaler = StandardScaler()

# %% [markdown]
# #### Fit the scaler

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %% [markdown]
# #### Transform the data

# %%
X_train_std = scaler.transform(X_train)
X_test_std = scaler.transform(X_test)

print('Dataframe after standardizing features:\n')
print(pd.DataFrame(X_train_std, columns=['PetalLengthCm', 'PetalWidthCm']).head())
# Out:
# Dataframe after standardizing features:
#
#    PetalLengthCm  PetalWidthCm
# 0      -1.283919     -1.043212
# 1      -1.339986     -1.302933
# 2       0.734469      1.424136
# 3       0.342005     -0.004329
# 4      -0.106526      0.125532

# %%
# save the scaler to disk
filename = '../models/scaler_classification_iris.pkl'
pickle.dump(scaler, open(filename, 'wb'))
 
# load the scaler from disk
# scaler = pickle.load(open(filename, 'rb'))

# %% [markdown]
# ## 1. Create/Build model/classifier

# %%
# from sklearn.svm import SVC
svm = SVC(kernel='rbf', random_state=0, gamma=.10, C=1.0)

# %% [markdown]
# ## 2. Fit model
# Train the model.

# %%
svm.fit(X_train_std, y_train)
# Out:
# SVC(gamma=0.1, random_state=0)

# %% [markdown]
# ## 3. Evaluate the model

# %%
print('The accuracy of the svm classifier on training data is {:.2f} out of 1'.format(svm.score(X_train_std, y_train)))
print('The accuracy of the svm classifier on test data is {:.2f} out of 1'.format(svm.score(X_test_std, y_test)))
# Out:
# The accuracy of the svm classifier on training data is 0.96 out of 1
# The accuracy of the svm classifier on test data is 0.97 out of 1

# %%
plot_decision_regions(X_test_std, y_test, svm)

# %%
# If you're satisfied with the model, save it to disk
filename = '../models/classifier_SVC.pkl'
pickle.dump(svm, open(filename, 'wb'))
 
# load the model from disk
# svm = pickle.load(open(filename, 'rb'))
# result = svm.predict(X_test)

# %% [markdown]
# ## Hands on
# Using the same approach create, fit and evaluate a KNN classification model.
#
# Remember to define an odd number of neighbors.
# To classify in Euclidean space use p=2 and 'minkowski' metric.
#
# [KNeighborsClassifier manual](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html)
#
# ## KNN
# ## 1. Create/Build model/classifier

# %%
# from sklearn.neighbors import KNeighborsClassifier

# HANDS ON
# knn = KNeighborsClassifier(??, ??, ??)

knn = KNeighborsClassifier(n_neighbors=5, p=2, metric='minkowski')

# %% [markdown]
# ## 2. Fit model

# %%
# HANDS ON
# knn.fit(??, ??)

knn.fit(X_train_std, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ## 3. Evaluate the model

# %%
print('The accuracy of the knn classifier is {:.2f} out of 1 on training data'.format(knn.score(X_train_std, y_train)))
print('The accuracy of the knn classifier is {:.2f} out of 1 on test data'.format(knn.score(X_test_std, y_test)))
# Out:
# The accuracy of the knn classifier is 0.97 out of 1 on training data
# The accuracy of the knn classifier is 1.00 out of 1 on test data

# %%
plot_decision_regions(X_test_std, y_test, knn)

# %%
# If you're satisfied with the model, save it to disk
filename = '../models/classifier_knn.pkl'
pickle.dump(KNeighborsClassifier, open(filename, 'wb'))
 
# load the model from disk
# KNeighborsClassifier = pickle.load(open(filename, 'rb'))
# result = KNeighborsClassifier.predict(X_test)

# %% [markdown]
# _University of Zagreb Faculty of Electrical Engineering and Computing_
# _Laboratory for Renewable Energy Systems_
#
# _Course: AI bootcamp - basic_
# _Notebook: 2a_Classification_Iris_
# _Instructors: [Hrvoje Novak](mailto:hrvoje.novak@fer.hr)_
# _Intended user: XY_
# _Date: 1st January 1991_
#
# _References:_
# - _Iris dataset: https://archive.ics.uci.edu/dataset/53/iris_
# - _FISHER, R.A. (1936), THE USE OF MULTIPLE MEASUREMENTS IN TAXONOMIC PROBLEMS. Annals of Eugenics, 7: 179-188. https://doi.org/10.1111/j.1469-1809.1936.tb02137.x_
# - _Scikit-learn Decision Trees: https://scikit-learn.org/1.5/modules/tree.html_
# - _Scikit-learn Nearest Neighbors: https://scikit-learn.org/1.5/modules/neighbors.html#nearest-neighbors-classification_
# - _Scikit-learn KNClassifier: https://scikit-learn.org/1.5/modules/generated/sklearn.neighbors.KNeighborsClassifier.html#sklearn.neighbors.KNeighborsClassifier_
#
# _Website: [www.lares.fer.hr](https://www.lares.fer.hr/)_
# _Contact: [Hrvoje Novak](mailto:hrvoje.novak@fer.hr)_
